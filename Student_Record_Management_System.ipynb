# %% [markdown]
# <a href="https://colab.research.google.com/github/SherjinCruz/Student_Record_Management_System/blob/main/Student_Record_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = [
    {'Roll Number':101,
    'Name': "John",
    'Marks in Python': 45,
    'Marks in Data Science': 56,
    'Marks in Mathematics': 68,
    },
    {'Roll Number':102,
    'Name': "Mary",
    'Marks in Python': 89,
    'Marks in Data Science': 90,
    'Marks in Mathematics': 89},
    {'Roll Number':103,
    'Name': 'Cruz',
    'Marks in Python': 45,
    'Marks in Data Science': 45,
    'Marks in Mathematics' : 45,
    }
]


# Add students
total_students = len(students)
print(total_students)

# #Display all Students
# for i in range(total_students):
#   name = students[i]["Name"]
#   print(name)

# # Search Students by roll number
# roll_number = int(input("Enter the roll number 10l, 102 or 103: "))

# if 101 == roll_number:
#   print(students[0])
# elif 102 == roll_number:
#   print(students[1])
# elif 103 == roll_number:
#   print(students[2])
# else:
#   print("write the correct number")

#Find Topper

for i in range(len(students)):
  if i == 0:
    total_marks_student1 = students[0]['Marks in Python'] \
    + students[0]['Marks in Data Science'] + \
    students[0]['Marks in Mathematics']
    print(total_marks_student1)

  elif i == 1:
    total_marks_student2 = students[1]['Marks in Python'] \
    + students[1]['Marks in Data Science'] + \
    students[0]['Marks in Mathematics']
    print(total_marks_student2)
  elif i == 2:
    total_marks_student3 = students[2]['Marks in Python'] \
    + students[2]['Marks in Data Science'] + \
    students[2]['Marks in Mathematics']
    print(total_marks_student3)
  else:
    break

    if int(total_marks_student1) > int(total_marks_student2) :
      if int(total_marks_student1) > int(total_marks_student3):
        print(f'Student 1 is topper')

      else:
        print(f'Student 3 is topper')

    elif int(total_marks_student2) > int(total_marks_student3) :
      if int(total_marks_student3) > int(total_marks_student1):
        print(f'Student 3 is topper')

      else:
        print(f'Student 2 is topper')
# Out:
# 3
# 169
# 247
# 135
